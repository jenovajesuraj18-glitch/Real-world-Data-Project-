# %% [markdown]
# **Task 1:Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Task 2:Load Dataset**

# %%
df = pd.read_csv('/content/Employee data (1).csv')

# %% [markdown]
# **Task 3 3: Display First 5 Rows**

# %%
df.head()
# Out:
#     id  gender       bdate  educ    jobcat   salary  salbegin  jobtime  \
# 0  1.0    Male  1952-02-03    15   Manager  57000.0   27000.0     98.0
# 1  2.0    Male  1958-05-23    16  Clerical  40200.0   18750.0     98.0
# 2  3.0  Female  1929-07-26    12  Clerical  21450.0   12000.0     98.0
# 3  4.0  Female  1947-04-15     8  Clerical  21900.0   13200.0     98.0
# 4  5.0    Male  1955-02-09    15  Clerical  45000.0   21000.0     98.0
#
#   prevexp minority
# 0   144.0       No
# 1    36.0       No
# 2   381.0       No
# 3   190.0       No
# 4   138.0       No

# %% [markdown]
# **Task  4: Check Number of Rows and Columns**

# %%
df.shape
# Out:
# (474, 10)

# %% [markdown]
# **Task 5: View Column Names**

# %%
df.columns
# Out:
# Index(['id', 'gender', 'bdate', 'educ', 'jobcat', 'salary', 'salbegin',
#        'jobtime', 'prevexp', 'minority'],
#       dtype='object')

# %% [markdown]
# **Task 6: Dataset Information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        474 non-null    float64
#  1   gender    474 non-null    object
#  2   bdate     473 non-null    object
#  3   educ      474 non-null    int64
#  4   jobcat    474 non-null    object
#  5   salary    474 non-null    float64
#  6   salbegin  474 non-null    float64
#  7   jobtime   474 non-null    float64
#  8   prevexp   474 non-null    object
#  9   minority  474 non-null    object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 37.2+ KB

# %% [markdown]
# **Task 7: Statistical Summary**

# %%
df.describe()
# Out:
#                id        educ         salary      salbegin     jobtime
# count  474.000000  474.000000     474.000000    474.000000  474.000000
# mean   237.500000   13.491561   34419.567511  17016.086498   81.109705
# std    136.976275    2.884846   17075.661465   7870.638154   10.060945
# min      1.000000    8.000000   15750.000000   9000.000000   63.000000
# 25%    119.250000   12.000000   24000.000000  12487.500000   72.000000
# 50%    237.500000   12.000000   28875.000000  15000.000000   81.000000
# 75%    355.750000   15.000000   36937.500000  17490.000000   90.000000
# max    474.000000   21.000000  135000.000000  79980.000000   98.000000

# %% [markdown]
# **Task 8: Check Missing Values**

# %%
df.isnull().sum()
# Out:
# id          0
# gender      0
# bdate       1
# educ        0
# jobcat      0
# salary      0
# salbegin    0
# jobtime     0
# prevexp     0
# minority    0
# dtype: int64

# %% [markdown]
# **Task 9: Salary Distribution Graph**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['salary'], bins=20)
plt.title("Salary Distribution")
plt.show()

# %% [markdown]
# **Task 10: Male vs Female Employees**

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='gender', data=df)
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# **Task 11: Education Level Distribution**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['educ'], bins=10)
plt.title("Education Level")
plt.show()

# %% [markdown]
# **Task 12: Salary by Gender**

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x='gender', y='salary', data=df)
plt.title("Salary by Gender")
plt.show()

# %% [markdown]
# **Task 13: Correlation Heatmap**

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# **Task 14: Findings**

# %% [markdown]
# Findings The dataset contains 474 employees and 10 attributes.
# Salary varies among employees.
# Gender distribution includes both males and females.
# Education level differs among employees.
# Some variables show positive correlation with salary.
